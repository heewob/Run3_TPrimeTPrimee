# %%
import ROOT as r
# Out:
# Welcome to JupyROOT 6.30/03

# %%
f = r.TFile.Open("john_test_numEvent10.root")

# %%
f.ls()
# Out:
# TFile**		john_test_numEvent10.root
#  TFile*		john_test_numEvent10.root
#   KEY: TDirectoryFile	selectionStudy_Et50;1	selectionStudy_Et50

# %%
f.cd("selectionStudy_Et50")
# Out:
# True

# %%
f.ls()
# Out:
# TFile**		john_test_numEvent10.root
#  TFile*		john_test_numEvent10.root
#   TDirectoryFile*		selectionStudy_Et50	selectionStudy_Et50
#    KEY: TTree	tree_nom_Et50;1	tree_nom_Et50
#   KEY: TDirectoryFile	selectionStudy_Et50;1	selectionStudy_Et50

# %%
t = f.Get("selectionStudy_Et50/tree_nom_Et50")

# %%
from pprint import pprint

# %%
pprint([b.GetName() for b in t.GetListOfBranches()])
# Out:
# ['passesPFHT',
#  'passesPFJet',
#  'nfatjets',
#  'nAK4',
#  'AK4_DeepJet_disc',
#  'nSuperJets',
#  'tot_nAK4_50',
#  'tot_nAK4_70',
#  'diSuperJet_mass',
#  'diSuperJet_mass_100',
#  'nfatjet_pre',
#  'totHT',
#  'jet_pt',
#  'jet_eta',
#  'jet_phi',
#  'AK8_fails_veto_map',
#  'fatjet_isHEM',
#  'jet_pre_isHEM',
#  'jet_isHEM',
#  'lab_nAK4',
#  'lab_AK4_pt',
#  'AK4_eta',
#  'AK4_phi',
#  'AK4_fails_veto_map',
#  'jet_mass',
#  'AK4_mass',
#  'dijetMassOne',
#  'dijetMassTwo',
#  'SJ_nAK4_50',
#  'SJ_nAK4_70',
#  'SJ_nAK4_100',
#  'SJ_nAK4_125',
#  'SJ_nAK4_150',
#  'SJ_nAK4_200',
#  'SJ_nAK4_300',
#  'SJ_nAK4_400',
#  'nHeavyAK8_pt400_M10',
#  'nHeavyAK8_pt400_M20',
#  'nHeavyAK8_pt400_M30',
#  'nHeavyAK8_pt300_M10',
#  'nHeavyAK8_pt300_M20',
#  'nHeavyAK8_pt300_M30',
#  'nHeavyAK8_pt200_M10',
#  'nHeavyAK8_pt200_M20',
#  'nHeavyAK8_pt200_M30',
#  'AK8_SJ_assignment',
#  'AK4_SJ_assignment',
#  'AK8_is_near_highE_CA4',
#  'lab_AK4_AK8_parent',
#  'AK4_is_near_highE_CA4',
#  'JEC_uncert_AK4',
#  'JEC_uncert_AK8',
#  'jet_lund_dR',
#  'jet_lund_kT',
#  'boosted_jet_lund_dR',
#  'boosted_jet_lund_kT',
#  'L_parallel',
#  'L_perpendicular',
#  'L_ratio',
#  'tau1',
#  'tau2',
#  'tau3',
#  'tau21',
#  'tau32',
#  'tau1COM',
#  'tau2COM',
#  'tau3COM',
#  'tau21COM',
#  'tau32COM',
#  'SJ_mass_50',
#  'SJ_mass_70',
#  'SJ_mass_100',
#  'SJ_mass_125',
#  'SJ_mass_150',
#  'SJ_mass_200',
#  'SJ_mass_300',
#  'SJ_mass_400',
#  'superJet_mass',
#  'posSJ_mass',
#  'negSJ_mass',
#  'SJ_AK4_50_mass',
#  'SJ_AK4_70_mass',
#  'AK4_m1',
#  'AK4_m2',
#  'AK4_m3',
#  'AK4_m4',
#  'nCategories',
#  'SJ1_decision',
#  'SJ2_decision',
#  'nAK8diJets',
#  'diAK8Jet_mass',
#  'fourAK8JetMass',
#  'eventNumber',
#  'process',
#  'jetMultiplicity',
#  'AK8_JER',
#  'nTrue_b_AK4',
#  'nTrue_c_AK4',
#  'nTrue_light_AK4',
#  'jet_bTagSF_b_T',
#  'jet_bTagSF_c_T',
#  'jet_bTagSF_light_T',
#  'jet_bTagSF_b_M',
#  'jet_bTagSF_c_M',
#  'jet_bTagSF_light_M',
#  'bTag_eventWeight_T_nom',
#  'bTag_eventWeight_M_nom',
#  'PU_eventWeight_nom',
#  'PU_eventWeight_up',
#  'PU_eventWeight_down',
#  'bTag_eventWeight_T_up',
#  'bTag_eventWeight_T_down',
#  'bTag_eventWeight_bc_T_up',
#  'bTag_eventWeight_bc_T_down',
#  'bTag_eventWeight_light_T_up',
#  'bTag_eventWeight_light_T_down',
#  'bTag_eventWeight_M_up',
#  'bTag_eventWeight_M_down',
#  'bTag_eventWeight_bc_M_up',
#  'bTag_eventWeight_bc_M_down',
#  'bTag_eventWeight_light_M_up',
#  'bTag_eventWeight_light_M_down',
#  'nGenBJets_AK4',
#  'AK4_partonFlavour',
#  'AK4_hadronFlavour',
#  'AK8_hadronFlavour',
#  'AK8_partonFlavour',
#  'ntrueInt']

# %%
t.Scan("tau21:tau32:tau21COM:tau32COM", "", "", 5, 0)
# Out:
# 20
# ***********************************************************************
# *    Row   * Instance *     tau21 *     tau32 *  tau21COM *  tau32COM *
# ***********************************************************************
# *        0 *        0 * 0.4663507 * 0.8250590 * 0.4547195 * 0.8286323 *
# *        0 *        1 * 0.4807518 * 0.9491740 * 0.4802924 * 0.9493453 *
# *        0 *        2 * 0.4880254 * 0.4438513 * 0.4872370 * 0.4414253 *
# *        0 *        3 * 0.5292683 * 0.8068515 * 0.5423643 * 0.7956012 *
# *        0 *        4 * 0.7930149 * 0.8033572 * 0.7941447 * 0.8022188 *
# *        1 *        0 * 0.3752223 * 0.4020163 * 0.3682079 * 0.4131149 *
# *        1 *        1 * 0.7444466 * 0.7011009 * 0.7427103 * 0.7106143 *
# *        1 *        2 * 0.4411884 * 0.8549400 * 0.4330636 * 0.8080144 *
# *        1 *        3 * 0.4508483 * 0.8417471 * 0.4040102 * 0.8127060 *
# *        2 *        0 * 0.6039437 * 0.5015438 * 0.5908577 * 0.5174623 *
# *        2 *        1 * 0.4226555 * 0.6462503 * 0.4472917 * 0.6588877 *
# *        2 *        2 * 0.1678607 * 0.8017161 * 0.1715328 * 0.8026527 *
# *        3 *        0 * 0.3703884 * 0.6203903 * 0.3414370 * 0.6316996 *
# *        3 *        1 * 0.5918983 * 0.6661595 * 0.6094896 * 0.6631599 *
# *        3 *        2 * 0.6041668 * 0.7553796 * 0.6081151 * 0.7308981 *
# *        3 *        3 * 0.2406743 * 0.8937017 * 0.2527873 * 0.8930913 *
# *        4 *        0 * 0.7734274 * 0.6222908 * 0.7722947 * 0.6208286 *
# *        4 *        1 * 0.4415928 * 0.9252969 * 0.4185748 * 0.9175218 *
# *        4 *        2 * 0.2961091 * 0.8442302 * 0.2920251 * 0.8416758 *
# *        4 *        3 * 0.1644413 * 0.8020994 * 0.1640586 * 0.8018612 *
# ***********************************************************************
